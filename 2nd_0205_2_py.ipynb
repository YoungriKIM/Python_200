# %% [markdown]
# <a href="https://colab.research.google.com/github/YoungriKIM/Python_200/blob/main/2nd_0205_2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 2등 모델 해킹
# 참고 : https://dacon.io/competitions/official/235626/codeshare/1679?page=1&dtype=recent&ptype=pub

# from google.colab import drive
# drive.mount('/content/drive')


import numpy as np
import pandas as pd
import tensorflow as tf
import os
import matplotlib.pyplot as plt
from numpy import expand_dims
from sklearn.model_selection import StratifiedKFold, train_test_split
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, BatchNormalization, Dropout
from tensorflow.keras.models import Sequential, Model, load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.utils import np_utils
from tensorflow.keras.applications.efficientnet import EfficientNetB7
from keras.optimizers import Adam, RMSprop
from tensorflow.keras import optimizers
from keras.utils import np_utils
from keras import backend as bek
import cv2 #openCV
import gc
from tensorflow.python.keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from sklearn import metrics


# dataset 불러오기
train = pd.read_csv('/content/drive/MyDrive/colab_data/dacon3/train.csv')
test = pd.read_csv('/content/drive/MyDrive/colab_data/dacon3/test.csv')

print('가능한~')

# 필요 없는 칼럼 버리고 +넘파이화 +리쉐잎
x_train = train.drop(['id', 'digit', 'letter'], axis=1).values
x_train = x_train.reshape(-1, 28, 28, 1)
# 0~20 사이 0으로 수렴
x_train = np.where((x_train<=20)&(x_train!=0) ,0.,x_train)
# scaler + float32로 변경
x_train = x_train/255
x_train = x_train.astype('float32')

# y 지정
y = train['digit']
# y 벡터화 0~9까지 10가지
y_train = np.zeros((len(y), len(y.unique())))  # 총 행의수 , 10(0~9)
for i, digit in enumerate(y):
    y_train[i, digit] = 1

# x_train 컬러화 + 특성 증폭 ------------
# 까만 도화지 준비
train_224=np.zeros([2048,56,56,3],dtype=np.float32)

for i, s in enumerate(x_train):
    converted = cv2.cvtColor(s, cv2.COLOR_GRAY2RGB)
    resized = cv2.resize(converted,(56,56),interpolation = cv2.INTER_CUBIC)
    del converted
    train_224[i] = resized
    del resized
    bek.clear_session()
    gc.collect()

print('가능한~2')

# 이미지 제너레이터 정의
datagen = ImageDataGenerator(
        width_shift_range=0.05,
        height_shift_range=0.05,
        zoom_range=0.15,
        rotation_range = 10,
        validation_split=0.2)

valgen = ImageDataGenerator()

# callbacks + 모델 정의
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.callbacks import EarlyStopping
def create_model() :
    
  effnet = tf.keras.applications.EfficientNetB3(
      include_top=True,
      weights=None,
      input_shape=(56,56,3),
      classes=10,
      classifier_activation="softmax",
  )
  model = Sequential()
  model.add(effnet)


  model.compile(loss="categorical_crossentropy",
              optimizer=RMSprop(lr=initial_learningrate),
              metrics=['accuracy'])
  return model

initial_learningrate=2e-3  
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import KFold
kfold = RepeatedKFold(n_splits=5, n_repeats=10, random_state=40)
cvscores = []
Fold = 1
results = np.zeros((20480,10) )
def lr_decay(epoch):#lrv
    return initial_learningrate * 0.99 ** epoch


# 테스트 데이터 지정 
x_test = test.drop(['id', 'letter'], axis=1).values
x_test = x_test.reshape(-1, 28, 28, 1)
x_test = np.where((x_test<=20)&(x_test!=0) ,0.,x_test)
# x_test = np.where(x_test>=145,255.,x_test)
x_test = x_test/255
x_test = x_test.astype('float32')

test_224=np.zeros([20480,56,56,3],dtype=np.float32)


for i, s in enumerate(x_test):
    converted = cv2.cvtColor(s, cv2.COLOR_GRAY2RGB)
    resized = cv2.resize(converted,(56,56),interpolation = cv2.INTER_CUBIC)
    del converted
    test_224[i] = resized
    del resized

bek.clear_session()
gc.collect()

# 최종 데이터 정의
results = np.zeros((20480,10),dtype=np.float32)

for train, val in kfold.split(train_224): 
    # if Fold<25:
    #   Fold+=1
    #   continue
    
    initial_learningrate=2e-3  
    es = EarlyStopping(monitor='val_loss', verbose=1, patience=50)      
    filepath_val_acc="/content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_2"+str(Fold)+".ckpt"
    checkpoint_val_acc = ModelCheckpoint(filepath_val_acc, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max',save_weights_only=True)

    gc.collect()
    bek.clear_session()
    print ('Fold: ',Fold)
    
    X_train = train_224[train]
    X_val = train_224[val]
    X_train = X_train.astype('float32')
    X_val = X_val.astype('float32')
    Y_train = y_train[train]
    Y_val = y_train[val]

    model = create_model()


    training_generator = datagen.flow(X_train, Y_train, batch_size=4,seed=7,shuffle=True)
    validation_generator = valgen.flow(X_val, Y_val, batch_size=4,seed=7,shuffle=True)
    model.fit(training_generator,epochs=150,callbacks=[LearningRateScheduler(lr_decay),es,checkpoint_val_acc],
               shuffle=True,
               validation_data=validation_generator,
               steps_per_epoch =len(X_train)//4
               )
    del X_train
    del X_val
    del Y_train
    del Y_val

    gc.collect()
    bek.clear_session()
    model.load_weights(filepath_val_acc)
    results = results + model.predict(test_224)
    
    Fold = Fold +1
    
submission = pd.read_csv('/content/drive/MyDrive/colab_data/dacon3/submission.csv')
submission['digit'] = np.argmax(results, axis=1)
submission.head()
submission.to_csv('/content/drive/MyDrive/colab_data/dacon3/large_0204_2.csv', index = False)

# ======================================================
# 오리지널 제일 왼쪽에서 ing
# 배치 4로 이 파일 ing
# Out:
# 가능한~
# 가능한~2
# Fold:  1
# Epoch 1/150
# 409/409 [==============================] - 61s 91ms/step - loss: 6.9087 - accuracy: 0.1035 - val_loss: 2.4332 - val_accuracy: 0.0878
#
# Epoch 00001: val_accuracy improved from -inf to 0.08780, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 2/150
# 409/409 [==============================] - 35s 85ms/step - loss: 3.0065 - accuracy: 0.0929 - val_loss: 3.1786 - val_accuracy: 0.1220
#
# Epoch 00002: val_accuracy improved from 0.08780 to 0.12195, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 3/150
# 409/409 [==============================] - 35s 86ms/step - loss: 2.8464 - accuracy: 0.0986 - val_loss: 2.5133 - val_accuracy: 0.1049
#
# Epoch 00003: val_accuracy did not improve from 0.12195
# Epoch 4/150
# 409/409 [==============================] - 35s 85ms/step - loss: 2.7152 - accuracy: 0.1088 - val_loss: 2.6638 - val_accuracy: 0.0878
#
# Epoch 00004: val_accuracy did not improve from 0.12195
# Epoch 5/150
# 409/409 [==============================] - 35s 86ms/step - loss: 2.6856 - accuracy: 0.1072 - val_loss: 2.8296 - val_accuracy: 0.0951
#
# Epoch 00005: val_accuracy did not improve from 0.12195
# Epoch 6/150
# 409/409 [==============================] - 35s 85ms/step - loss: 2.6116 - accuracy: 0.0937 - val_loss: 2.4114 - val_accuracy: 0.0951
#
# Epoch 00006: val_accuracy did not improve from 0.12195
# Epoch 7/150
# 409/409 [==============================] - 35s 85ms/step - loss: 2.5314 - accuracy: 0.1282 - val_loss: 2.8983 - val_accuracy: 0.1073
#
# Epoch 00007: val_accuracy did not improve from 0.12195
# Epoch 8/150
# 409/409 [==============================] - 35s 86ms/step - loss: 2.4353 - accuracy: 0.1360 - val_loss: 2.1473 - val_accuracy: 0.1878
#
# Epoch 00008: val_accuracy improved from 0.12195 to 0.18780, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 9/150
# 409/409 [==============================] - 35s 85ms/step - loss: 2.3369 - accuracy: 0.1634 - val_loss: 2.0369 - val_accuracy: 0.2195
#
# Epoch 00009: val_accuracy improved from 0.18780 to 0.21951, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 10/150
# 409/409 [==============================] - 35s 86ms/step - loss: 2.1844 - accuracy: 0.2020 - val_loss: 2.0130 - val_accuracy: 0.2463
#
# Epoch 00010: val_accuracy improved from 0.21951 to 0.24634, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 11/150
# 409/409 [==============================] - 35s 86ms/step - loss: 2.0934 - accuracy: 0.2118 - val_loss: 1.9895 - val_accuracy: 0.2341
#
# Epoch 00011: val_accuracy did not improve from 0.24634
# Epoch 12/150
# 409/409 [==============================] - 35s 85ms/step - loss: 1.9781 - accuracy: 0.2646 - val_loss: 1.8138 - val_accuracy: 0.3439
#
# Epoch 00012: val_accuracy improved from 0.24634 to 0.34390, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 13/150
# 409/409 [==============================] - 35s 86ms/step - loss: 1.9517 - accuracy: 0.2974 - val_loss: 1.7057 - val_accuracy: 0.3756
#
# Epoch 00013: val_accuracy improved from 0.34390 to 0.37561, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 14/150
# 409/409 [==============================] - 35s 85ms/step - loss: 1.7607 - accuracy: 0.3651 - val_loss: 1.6580 - val_accuracy: 0.4195
#
# Epoch 00014: val_accuracy improved from 0.37561 to 0.41951, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 15/150
# 409/409 [==============================] - 35s 85ms/step - loss: 1.7010 - accuracy: 0.3729 - val_loss: 1.7836 - val_accuracy: 0.3268
#
# Epoch 00015: val_accuracy did not improve from 0.41951
# Epoch 16/150
# 409/409 [==============================] - 35s 85ms/step - loss: 1.6512 - accuracy: 0.4258 - val_loss: 1.5619 - val_accuracy: 0.5024
#
# Epoch 00016: val_accuracy improved from 0.41951 to 0.50244, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 17/150
# 409/409 [==============================] - 35s 85ms/step - loss: 1.5891 - accuracy: 0.4542 - val_loss: 1.4760 - val_accuracy: 0.4585
#
# Epoch 00017: val_accuracy did not improve from 0.50244
# Epoch 18/150
# 409/409 [==============================] - 36s 87ms/step - loss: 1.4704 - accuracy: 0.4961 - val_loss: 1.6637 - val_accuracy: 0.4756
#
# Epoch 00018: val_accuracy did not improve from 0.50244
# Epoch 19/150
# 409/409 [==============================] - 34s 83ms/step - loss: 1.3851 - accuracy: 0.5204 - val_loss: 1.2521 - val_accuracy: 0.6171
#
# Epoch 00019: val_accuracy improved from 0.50244 to 0.61707, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 20/150
# 409/409 [==============================] - 34s 83ms/step - loss: 1.3629 - accuracy: 0.5530 - val_loss: 1.2365 - val_accuracy: 0.6073
#
# Epoch 00020: val_accuracy did not improve from 0.61707
# Epoch 21/150
# 409/409 [==============================] - 34s 83ms/step - loss: 1.1460 - accuracy: 0.6191 - val_loss: 1.2286 - val_accuracy: 0.5707
#
# Epoch 00021: val_accuracy did not improve from 0.61707
# Epoch 22/150
# 409/409 [==============================] - 34s 83ms/step - loss: 1.1679 - accuracy: 0.6345 - val_loss: 1.6490 - val_accuracy: 0.5390
#
# Epoch 00022: val_accuracy did not improve from 0.61707
# Epoch 23/150
# 409/409 [==============================] - 34s 83ms/step - loss: 1.1196 - accuracy: 0.6437 - val_loss: 1.4657 - val_accuracy: 0.5659
#
# Epoch 00023: val_accuracy did not improve from 0.61707
# Epoch 24/150
# 409/409 [==============================] - 34s 82ms/step - loss: 1.0161 - accuracy: 0.6972 - val_loss: 0.9423 - val_accuracy: 0.7146
#
# Epoch 00024: val_accuracy improved from 0.61707 to 0.71463, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 25/150
# 409/409 [==============================] - 34s 84ms/step - loss: 0.9241 - accuracy: 0.7281 - val_loss: 1.0579 - val_accuracy: 0.7049
#
# Epoch 00025: val_accuracy did not improve from 0.71463
# Epoch 26/150
# 409/409 [==============================] - 34s 83ms/step - loss: 0.8750 - accuracy: 0.7316 - val_loss: 1.1128 - val_accuracy: 0.6829
#
# Epoch 00026: val_accuracy did not improve from 0.71463
# Epoch 27/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.9133 - accuracy: 0.7386 - val_loss: 1.1505 - val_accuracy: 0.6780
#
# Epoch 00027: val_accuracy did not improve from 0.71463
# Epoch 28/150
# 409/409 [==============================] - 34s 83ms/step - loss: 0.8238 - accuracy: 0.7530 - val_loss: 1.2986 - val_accuracy: 0.6463
#
# Epoch 00028: val_accuracy did not improve from 0.71463
# Epoch 29/150
# 409/409 [==============================] - 34s 83ms/step - loss: 0.7608 - accuracy: 0.7832 - val_loss: 0.8896 - val_accuracy: 0.7732
#
# Epoch 00029: val_accuracy improved from 0.71463 to 0.77317, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 30/150
# 409/409 [==============================] - 34s 84ms/step - loss: 0.7451 - accuracy: 0.7941 - val_loss: 0.9216 - val_accuracy: 0.7317
#
# Epoch 00030: val_accuracy did not improve from 0.77317
# Epoch 31/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.7075 - accuracy: 0.8053 - val_loss: 0.8462 - val_accuracy: 0.7341
#
# Epoch 00031: val_accuracy did not improve from 0.77317
# Epoch 32/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.6906 - accuracy: 0.7963 - val_loss: 1.1314 - val_accuracy: 0.7122
#
# Epoch 00032: val_accuracy did not improve from 0.77317
# Epoch 33/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.7349 - accuracy: 0.7997 - val_loss: 1.1477 - val_accuracy: 0.6780
#
# Epoch 00033: val_accuracy did not improve from 0.77317
# Epoch 34/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.7510 - accuracy: 0.7871 - val_loss: 0.8656 - val_accuracy: 0.7463
#
# Epoch 00034: val_accuracy did not improve from 0.77317
# Epoch 35/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.6187 - accuracy: 0.8182 - val_loss: 1.0221 - val_accuracy: 0.7171
#
# Epoch 00035: val_accuracy did not improve from 0.77317
# Epoch 36/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.6199 - accuracy: 0.8270 - val_loss: 1.0507 - val_accuracy: 0.7268
#
# Epoch 00036: val_accuracy did not improve from 0.77317
# Epoch 37/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.6090 - accuracy: 0.8200 - val_loss: 1.0402 - val_accuracy: 0.7390
#
# Epoch 00037: val_accuracy did not improve from 0.77317
# Epoch 38/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.5572 - accuracy: 0.8509 - val_loss: 0.9482 - val_accuracy: 0.7341
#
# Epoch 00038: val_accuracy did not improve from 0.77317
# Epoch 39/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.5702 - accuracy: 0.8319 - val_loss: 1.2447 - val_accuracy: 0.6610
#
# Epoch 00039: val_accuracy did not improve from 0.77317
# Epoch 40/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.5014 - accuracy: 0.8590 - val_loss: 0.9306 - val_accuracy: 0.7780
#
# Epoch 00040: val_accuracy improved from 0.77317 to 0.77805, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 41/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.5853 - accuracy: 0.8406 - val_loss: 1.1931 - val_accuracy: 0.6854
#
# Epoch 00041: val_accuracy did not improve from 0.77805
# Epoch 42/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.4422 - accuracy: 0.8911 - val_loss: 1.1805 - val_accuracy: 0.7195
#
# Epoch 00042: val_accuracy did not improve from 0.77805
# Epoch 43/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.4984 - accuracy: 0.8567 - val_loss: 1.2029 - val_accuracy: 0.7220
#
# Epoch 00043: val_accuracy did not improve from 0.77805
# Epoch 44/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.4619 - accuracy: 0.8666 - val_loss: 0.9555 - val_accuracy: 0.7634
#
# Epoch 00044: val_accuracy did not improve from 0.77805
# Epoch 45/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.4048 - accuracy: 0.8923 - val_loss: 1.2930 - val_accuracy: 0.7073
#
# Epoch 00045: val_accuracy did not improve from 0.77805
# Epoch 46/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.4440 - accuracy: 0.8689 - val_loss: 0.8785 - val_accuracy: 0.7951
#
# Epoch 00046: val_accuracy improved from 0.77805 to 0.79512, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 47/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.4185 - accuracy: 0.8875 - val_loss: 0.7915 - val_accuracy: 0.8000
#
# Epoch 00047: val_accuracy improved from 0.79512 to 0.80000, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 48/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.4422 - accuracy: 0.8760 - val_loss: 1.0651 - val_accuracy: 0.7512
#
# Epoch 00048: val_accuracy did not improve from 0.80000
# Epoch 49/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.4481 - accuracy: 0.8749 - val_loss: 1.2160 - val_accuracy: 0.7268
#
# Epoch 00049: val_accuracy did not improve from 0.80000
# Epoch 50/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.3793 - accuracy: 0.8952 - val_loss: 1.0285 - val_accuracy: 0.7610
#
# Epoch 00050: val_accuracy did not improve from 0.80000
# Epoch 51/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.4892 - accuracy: 0.8807 - val_loss: 1.1652 - val_accuracy: 0.7390
#
# Epoch 00051: val_accuracy did not improve from 0.80000
# Epoch 52/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.2918 - accuracy: 0.9134 - val_loss: 0.8443 - val_accuracy: 0.7805
#
# Epoch 00052: val_accuracy did not improve from 0.80000
# Epoch 53/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.3804 - accuracy: 0.8954 - val_loss: 1.1498 - val_accuracy: 0.7439
#
# Epoch 00053: val_accuracy did not improve from 0.80000
# Epoch 54/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.3895 - accuracy: 0.8902 - val_loss: 0.9508 - val_accuracy: 0.7659
#
# Epoch 00054: val_accuracy did not improve from 0.80000
# Epoch 55/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.3072 - accuracy: 0.9203 - val_loss: 0.8522 - val_accuracy: 0.7829
#
# Epoch 00055: val_accuracy did not improve from 0.80000
# Epoch 56/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.3493 - accuracy: 0.9097 - val_loss: 1.0499 - val_accuracy: 0.7634
#
# Epoch 00056: val_accuracy did not improve from 0.80000
# Epoch 57/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.3360 - accuracy: 0.9043 - val_loss: 1.2959 - val_accuracy: 0.7000
#
# Epoch 00057: val_accuracy did not improve from 0.80000
# Epoch 58/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.3340 - accuracy: 0.9152 - val_loss: 1.3429 - val_accuracy: 0.7146
#
# Epoch 00058: val_accuracy did not improve from 0.80000
# Epoch 59/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.3521 - accuracy: 0.9079 - val_loss: 1.8194 - val_accuracy: 0.6439
#
# Epoch 00059: val_accuracy did not improve from 0.80000
# Epoch 60/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.3106 - accuracy: 0.9196 - val_loss: 0.9188 - val_accuracy: 0.7976
#
# Epoch 00060: val_accuracy did not improve from 0.80000
# Epoch 61/150
# 409/409 [==============================] - 35s 87ms/step - loss: 0.3413 - accuracy: 0.9140 - val_loss: 1.0425 - val_accuracy: 0.7634
#
# Epoch 00061: val_accuracy did not improve from 0.80000
# Epoch 62/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.2973 - accuracy: 0.9265 - val_loss: 1.1481 - val_accuracy: 0.7293
#
# Epoch 00062: val_accuracy did not improve from 0.80000
# Epoch 63/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2767 - accuracy: 0.9357 - val_loss: 1.0689 - val_accuracy: 0.7488
#
# Epoch 00063: val_accuracy did not improve from 0.80000
# Epoch 64/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2467 - accuracy: 0.9405 - val_loss: 1.1259 - val_accuracy: 0.7732
#
# Epoch 00064: val_accuracy did not improve from 0.80000
# Epoch 65/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2524 - accuracy: 0.9435 - val_loss: 1.1706 - val_accuracy: 0.7439
#
# Epoch 00065: val_accuracy did not improve from 0.80000
# Epoch 66/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2361 - accuracy: 0.9316 - val_loss: 1.2256 - val_accuracy: 0.7537
#
# Epoch 00066: val_accuracy did not improve from 0.80000
# Epoch 67/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2369 - accuracy: 0.9430 - val_loss: 1.3722 - val_accuracy: 0.7171
#
# Epoch 00067: val_accuracy did not improve from 0.80000
# Epoch 68/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2793 - accuracy: 0.9352 - val_loss: 1.4425 - val_accuracy: 0.7073
#
# Epoch 00068: val_accuracy did not improve from 0.80000
# Epoch 69/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2208 - accuracy: 0.9337 - val_loss: 1.5075 - val_accuracy: 0.7073
#
# Epoch 00069: val_accuracy did not improve from 0.80000
# Epoch 70/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.2401 - accuracy: 0.9371 - val_loss: 0.8934 - val_accuracy: 0.7927
#
# Epoch 00070: val_accuracy did not improve from 0.80000
# Epoch 71/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2625 - accuracy: 0.9284 - val_loss: 1.1881 - val_accuracy: 0.7610
#
# Epoch 00071: val_accuracy did not improve from 0.80000
# Epoch 72/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.2390 - accuracy: 0.9393 - val_loss: 1.2879 - val_accuracy: 0.7561
#
# Epoch 00072: val_accuracy did not improve from 0.80000
# Epoch 73/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2153 - accuracy: 0.9408 - val_loss: 1.2388 - val_accuracy: 0.7659
#
# Epoch 00073: val_accuracy did not improve from 0.80000
# Epoch 74/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2170 - accuracy: 0.9488 - val_loss: 1.2218 - val_accuracy: 0.7756
#
# Epoch 00074: val_accuracy did not improve from 0.80000
# Epoch 75/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.1808 - accuracy: 0.9487 - val_loss: 1.1502 - val_accuracy: 0.7683
#
# Epoch 00075: val_accuracy did not improve from 0.80000
# Epoch 76/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2693 - accuracy: 0.9365 - val_loss: 1.4041 - val_accuracy: 0.7000
#
# Epoch 00076: val_accuracy did not improve from 0.80000
# Epoch 77/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2246 - accuracy: 0.9293 - val_loss: 1.1450 - val_accuracy: 0.7756
#
# Epoch 00077: val_accuracy did not improve from 0.80000
# Epoch 78/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.1799 - accuracy: 0.9540 - val_loss: 1.0847 - val_accuracy: 0.7805
#
# Epoch 00078: val_accuracy did not improve from 0.80000
# Epoch 79/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.2135 - accuracy: 0.9458 - val_loss: 1.3819 - val_accuracy: 0.7073
#
# Epoch 00079: val_accuracy did not improve from 0.80000
# Epoch 80/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2183 - accuracy: 0.9429 - val_loss: 1.2852 - val_accuracy: 0.7561
#
# Epoch 00080: val_accuracy did not improve from 0.80000
# Epoch 81/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2052 - accuracy: 0.9488 - val_loss: 1.1139 - val_accuracy: 0.7707
#
# Epoch 00081: val_accuracy did not improve from 0.80000
# Epoch 82/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.1767 - accuracy: 0.9594 - val_loss: 1.1372 - val_accuracy: 0.7854
#
# Epoch 00082: val_accuracy did not improve from 0.80000
# Epoch 83/150
# 409/409 [==============================] - 37s 89ms/step - loss: 0.1619 - accuracy: 0.9574 - val_loss: 1.2551 - val_accuracy: 0.7756
#
# Epoch 00083: val_accuracy did not improve from 0.80000
# Epoch 84/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.1365 - accuracy: 0.9611 - val_loss: 1.3954 - val_accuracy: 0.7415
#
# Epoch 00084: val_accuracy did not improve from 0.80000
# Epoch 85/150
# 409/409 [==============================] - 35s 85ms/step - loss: 0.2690 - accuracy: 0.9489 - val_loss: 1.1977 - val_accuracy: 0.8024
#
# Epoch 00085: val_accuracy improved from 0.80000 to 0.80244, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 86/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.1973 - accuracy: 0.9468 - val_loss: 1.2347 - val_accuracy: 0.7756
#
# Epoch 00086: val_accuracy did not improve from 0.80244
# Epoch 87/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.1473 - accuracy: 0.9665 - val_loss: 1.0748 - val_accuracy: 0.8122
#
# Epoch 00087: val_accuracy improved from 0.80244 to 0.81220, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_21.ckpt
# Epoch 88/150
# 409/409 [==============================] - 35s 87ms/step - loss: 0.1884 - accuracy: 0.9575 - val_loss: 1.0539 - val_accuracy: 0.7829
#
# Epoch 00088: val_accuracy did not improve from 0.81220
# Epoch 89/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.1827 - accuracy: 0.9550 - val_loss: 1.3394 - val_accuracy: 0.7610
#
# Epoch 00089: val_accuracy did not improve from 0.81220
# Epoch 90/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.1805 - accuracy: 0.9569 - val_loss: 1.0494 - val_accuracy: 0.7805
#
# Epoch 00090: val_accuracy did not improve from 0.81220
# Epoch 91/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.1342 - accuracy: 0.9666 - val_loss: 1.3977 - val_accuracy: 0.7317
#
# Epoch 00091: val_accuracy did not improve from 0.81220
# Epoch 92/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.1823 - accuracy: 0.9605 - val_loss: 1.2627 - val_accuracy: 0.7659
#
# Epoch 00092: val_accuracy did not improve from 0.81220
# Epoch 93/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.2086 - accuracy: 0.9588 - val_loss: 1.1639 - val_accuracy: 0.7610
#
# Epoch 00093: val_accuracy did not improve from 0.81220
# Epoch 94/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.1732 - accuracy: 0.9646 - val_loss: 1.2545 - val_accuracy: 0.7756
#
# Epoch 00094: val_accuracy did not improve from 0.81220
# Epoch 95/150
# 409/409 [==============================] - 35s 87ms/step - loss: 0.1594 - accuracy: 0.9691 - val_loss: 1.2323 - val_accuracy: 0.7854
#
# Epoch 00095: val_accuracy did not improve from 0.81220
# Epoch 96/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.2035 - accuracy: 0.9634 - val_loss: 1.2044 - val_accuracy: 0.7878
#
# Epoch 00096: val_accuracy did not improve from 0.81220
# Epoch 97/150
# 409/409 [==============================] - 35s 86ms/step - loss: 0.1301 - accuracy: 0.9663 - val_loss: 1.2965 - val_accuracy: 0.7341
#
# Epoch 00097: val_accuracy did not improve from 0.81220
# Epoch 00097: early stopping
# Fold:  2
# Epoch 1/150
# 409/409 [==============================] - 63s 94ms/step - loss: 6.2976 - accuracy: 0.0942 - val_loss: 3.3836 - val_accuracy: 0.1122
#
# Epoch 00001: val_accuracy improved from -inf to 0.11220, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 2/150
# 409/409 [==============================] - 36s 88ms/step - loss: 2.9553 - accuracy: 0.1036 - val_loss: 2.3917 - val_accuracy: 0.0927
#
# Epoch 00002: val_accuracy did not improve from 0.11220
# Epoch 3/150
# 409/409 [==============================] - 35s 87ms/step - loss: 2.7965 - accuracy: 0.0941 - val_loss: 2.5346 - val_accuracy: 0.1244
#
# Epoch 00003: val_accuracy improved from 0.11220 to 0.12439, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 4/150
# 409/409 [==============================] - 36s 87ms/step - loss: 2.7389 - accuracy: 0.1004 - val_loss: 2.3994 - val_accuracy: 0.1244
#
# Epoch 00004: val_accuracy did not improve from 0.12439
# Epoch 5/150
# 409/409 [==============================] - 36s 87ms/step - loss: 2.7128 - accuracy: 0.1012 - val_loss: 2.3851 - val_accuracy: 0.1122
#
# Epoch 00005: val_accuracy did not improve from 0.12439
# Epoch 6/150
# 409/409 [==============================] - 35s 87ms/step - loss: 2.6307 - accuracy: 0.0825 - val_loss: 2.3528 - val_accuracy: 0.0927
#
# Epoch 00006: val_accuracy did not improve from 0.12439
# Epoch 7/150
# 409/409 [==============================] - 36s 87ms/step - loss: 2.5509 - accuracy: 0.1226 - val_loss: 2.4443 - val_accuracy: 0.0976
#
# Epoch 00007: val_accuracy did not improve from 0.12439
# Epoch 8/150
# 409/409 [==============================] - 35s 87ms/step - loss: 2.5384 - accuracy: 0.0833 - val_loss: 2.3701 - val_accuracy: 0.0927
#
# Epoch 00008: val_accuracy did not improve from 0.12439
# Epoch 9/150
# 409/409 [==============================] - 36s 87ms/step - loss: 2.4887 - accuracy: 0.1013 - val_loss: 2.3518 - val_accuracy: 0.0927
#
# Epoch 00009: val_accuracy did not improve from 0.12439
# Epoch 10/150
# 409/409 [==============================] - 36s 87ms/step - loss: 2.4712 - accuracy: 0.0971 - val_loss: 2.3526 - val_accuracy: 0.1366
#
# Epoch 00010: val_accuracy improved from 0.12439 to 0.13659, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 11/150
# 409/409 [==============================] - 36s 88ms/step - loss: 2.4004 - accuracy: 0.1096 - val_loss: 2.2895 - val_accuracy: 0.1122
#
# Epoch 00011: val_accuracy did not improve from 0.13659
# Epoch 12/150
# 409/409 [==============================] - 36s 87ms/step - loss: 2.3818 - accuracy: 0.1163 - val_loss: 2.2497 - val_accuracy: 0.1585
#
# Epoch 00012: val_accuracy improved from 0.13659 to 0.15854, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 13/150
# 409/409 [==============================] - 36s 88ms/step - loss: 2.3140 - accuracy: 0.1527 - val_loss: 2.1568 - val_accuracy: 0.1439
#
# Epoch 00013: val_accuracy did not improve from 0.15854
# Epoch 14/150
# 409/409 [==============================] - 36s 87ms/step - loss: 2.2303 - accuracy: 0.1696 - val_loss: 1.9653 - val_accuracy: 0.2878
#
# Epoch 00014: val_accuracy improved from 0.15854 to 0.28780, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 15/150
# 409/409 [==============================] - 36s 89ms/step - loss: 2.0822 - accuracy: 0.2133 - val_loss: 1.9353 - val_accuracy: 0.2585
#
# Epoch 00015: val_accuracy did not improve from 0.28780
# Epoch 16/150
# 409/409 [==============================] - 36s 87ms/step - loss: 1.9968 - accuracy: 0.2722 - val_loss: 1.7674 - val_accuracy: 0.3634
#
# Epoch 00016: val_accuracy improved from 0.28780 to 0.36341, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 17/150
# 409/409 [==============================] - 36s 87ms/step - loss: 1.9606 - accuracy: 0.2752 - val_loss: 1.5916 - val_accuracy: 0.4171
#
# Epoch 00017: val_accuracy improved from 0.36341 to 0.41707, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 18/150
# 409/409 [==============================] - 37s 90ms/step - loss: 1.8066 - accuracy: 0.3581 - val_loss: 1.7450 - val_accuracy: 0.3463
#
# Epoch 00018: val_accuracy did not improve from 0.41707
# Epoch 19/150
# 409/409 [==============================] - 36s 87ms/step - loss: 1.7433 - accuracy: 0.3920 - val_loss: 1.4693 - val_accuracy: 0.4634
#
# Epoch 00019: val_accuracy improved from 0.41707 to 0.46341, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 20/150
# 409/409 [==============================] - 35s 87ms/step - loss: 1.4961 - accuracy: 0.4739 - val_loss: 1.3659 - val_accuracy: 0.4976
#
# Epoch 00020: val_accuracy improved from 0.46341 to 0.49756, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 21/150
# 409/409 [==============================] - 36s 87ms/step - loss: 1.4623 - accuracy: 0.4848 - val_loss: 1.3747 - val_accuracy: 0.5293
#
# Epoch 00021: val_accuracy improved from 0.49756 to 0.52927, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 22/150
# 409/409 [==============================] - 36s 88ms/step - loss: 1.4083 - accuracy: 0.5306 - val_loss: 1.0781 - val_accuracy: 0.6220
#
# Epoch 00022: val_accuracy improved from 0.52927 to 0.62195, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 23/150
# 409/409 [==============================] - 36s 87ms/step - loss: 1.3416 - accuracy: 0.5412 - val_loss: 1.0743 - val_accuracy: 0.6220
#
# Epoch 00023: val_accuracy did not improve from 0.62195
# Epoch 24/150
# 409/409 [==============================] - 36s 88ms/step - loss: 1.3343 - accuracy: 0.5452 - val_loss: 0.9968 - val_accuracy: 0.6732
#
# Epoch 00024: val_accuracy improved from 0.62195 to 0.67317, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 25/150
# 409/409 [==============================] - 36s 87ms/step - loss: 1.2209 - accuracy: 0.5738 - val_loss: 1.1303 - val_accuracy: 0.6098
#
# Epoch 00025: val_accuracy did not improve from 0.67317
# Epoch 26/150
# 409/409 [==============================] - 35s 87ms/step - loss: 1.1678 - accuracy: 0.6099 - val_loss: 1.0589 - val_accuracy: 0.5976
#
# Epoch 00026: val_accuracy did not improve from 0.67317
# Epoch 27/150
# 409/409 [==============================] - 36s 87ms/step - loss: 1.1849 - accuracy: 0.6127 - val_loss: 1.2872 - val_accuracy: 0.6146
#
# Epoch 00027: val_accuracy did not improve from 0.67317
# Epoch 28/150
# 409/409 [==============================] - 37s 89ms/step - loss: 0.9863 - accuracy: 0.6812 - val_loss: 0.8717 - val_accuracy: 0.7000
#
# Epoch 00028: val_accuracy improved from 0.67317 to 0.70000, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 29/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.9480 - accuracy: 0.6702 - val_loss: 0.7941 - val_accuracy: 0.7341
#
# Epoch 00029: val_accuracy improved from 0.70000 to 0.73415, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 30/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.9204 - accuracy: 0.6900 - val_loss: 0.7731 - val_accuracy: 0.7146
#
# Epoch 00030: val_accuracy did not improve from 0.73415
# Epoch 31/150
# 409/409 [==============================] - 35s 87ms/step - loss: 0.9581 - accuracy: 0.6761 - val_loss: 1.1031 - val_accuracy: 0.6463
#
# Epoch 00031: val_accuracy did not improve from 0.73415
# Epoch 32/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.8451 - accuracy: 0.7325 - val_loss: 0.6799 - val_accuracy: 0.7683
#
# Epoch 00032: val_accuracy improved from 0.73415 to 0.76829, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 33/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.8617 - accuracy: 0.7235 - val_loss: 1.2069 - val_accuracy: 0.6683
#
# Epoch 00033: val_accuracy did not improve from 0.76829
# Epoch 34/150
# 409/409 [==============================] - 35s 87ms/step - loss: 0.7028 - accuracy: 0.7725 - val_loss: 0.8406 - val_accuracy: 0.7293
#
# Epoch 00034: val_accuracy did not improve from 0.76829
# Epoch 35/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.7842 - accuracy: 0.7724 - val_loss: 1.3572 - val_accuracy: 0.6098
#
# Epoch 00035: val_accuracy did not improve from 0.76829
# Epoch 36/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.7281 - accuracy: 0.7818 - val_loss: 0.6975 - val_accuracy: 0.7878
#
# Epoch 00036: val_accuracy improved from 0.76829 to 0.78780, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 37/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.7323 - accuracy: 0.7799 - val_loss: 0.7920 - val_accuracy: 0.7561
#
# Epoch 00037: val_accuracy did not improve from 0.78780
# Epoch 38/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.7028 - accuracy: 0.7909 - val_loss: 0.7209 - val_accuracy: 0.7805
#
# Epoch 00038: val_accuracy did not improve from 0.78780
# Epoch 39/150
# 409/409 [==============================] - 35s 87ms/step - loss: 0.6507 - accuracy: 0.8063 - val_loss: 0.9553 - val_accuracy: 0.7195
#
# Epoch 00039: val_accuracy did not improve from 0.78780
# Epoch 40/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.6201 - accuracy: 0.8095 - val_loss: 0.9946 - val_accuracy: 0.7098
#
# Epoch 00040: val_accuracy did not improve from 0.78780
# Epoch 41/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.6144 - accuracy: 0.8333 - val_loss: 0.8572 - val_accuracy: 0.7439
#
# Epoch 00041: val_accuracy did not improve from 0.78780
# Epoch 42/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.6143 - accuracy: 0.8277 - val_loss: 0.7375 - val_accuracy: 0.7927
#
# Epoch 00042: val_accuracy improved from 0.78780 to 0.79268, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 43/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.6465 - accuracy: 0.8270 - val_loss: 0.8852 - val_accuracy: 0.7366
#
# Epoch 00043: val_accuracy did not improve from 0.79268
# Epoch 44/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.5162 - accuracy: 0.8600 - val_loss: 0.8000 - val_accuracy: 0.7488
#
# Epoch 00044: val_accuracy did not improve from 0.79268
# Epoch 45/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.5471 - accuracy: 0.8425 - val_loss: 0.6194 - val_accuracy: 0.8171
#
# Epoch 00045: val_accuracy improved from 0.79268 to 0.81707, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 46/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.4888 - accuracy: 0.8577 - val_loss: 0.6041 - val_accuracy: 0.7951
#
# Epoch 00046: val_accuracy did not improve from 0.81707
# Epoch 47/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.4934 - accuracy: 0.8655 - val_loss: 0.6003 - val_accuracy: 0.8244
#
# Epoch 00047: val_accuracy improved from 0.81707 to 0.82439, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 48/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.4561 - accuracy: 0.8752 - val_loss: 1.1842 - val_accuracy: 0.6829
#
# Epoch 00048: val_accuracy did not improve from 0.82439
# Epoch 49/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.5186 - accuracy: 0.8638 - val_loss: 0.9903 - val_accuracy: 0.7000
#
# Epoch 00049: val_accuracy did not improve from 0.82439
# Epoch 50/150
# 409/409 [==============================] - 36s 89ms/step - loss: 0.4593 - accuracy: 0.8698 - val_loss: 0.6234 - val_accuracy: 0.8220
#
# Epoch 00050: val_accuracy did not improve from 0.82439
# Epoch 51/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.4609 - accuracy: 0.8766 - val_loss: 1.2254 - val_accuracy: 0.6902
#
# Epoch 00051: val_accuracy did not improve from 0.82439
# Epoch 52/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.5157 - accuracy: 0.8672 - val_loss: 0.8477 - val_accuracy: 0.7634
#
# Epoch 00052: val_accuracy did not improve from 0.82439
# Epoch 53/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.3941 - accuracy: 0.8933 - val_loss: 1.0226 - val_accuracy: 0.7024
#
# Epoch 00053: val_accuracy did not improve from 0.82439
# Epoch 54/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.3811 - accuracy: 0.8883 - val_loss: 0.7656 - val_accuracy: 0.7805
#
# Epoch 00054: val_accuracy did not improve from 0.82439
# Epoch 55/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.3730 - accuracy: 0.8919 - val_loss: 0.9181 - val_accuracy: 0.7537
#
# Epoch 00055: val_accuracy did not improve from 0.82439
# Epoch 56/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.3347 - accuracy: 0.8951 - val_loss: 0.7983 - val_accuracy: 0.7561
#
# Epoch 00056: val_accuracy did not improve from 0.82439
# Epoch 57/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.4038 - accuracy: 0.8810 - val_loss: 0.7695 - val_accuracy: 0.7902
#
# Epoch 00057: val_accuracy did not improve from 0.82439
# Epoch 58/150
# 409/409 [==============================] - 36s 89ms/step - loss: 0.3739 - accuracy: 0.8914 - val_loss: 0.8858 - val_accuracy: 0.7634
#
# Epoch 00058: val_accuracy did not improve from 0.82439
# Epoch 59/150
# 409/409 [==============================] - 37s 92ms/step - loss: 0.3335 - accuracy: 0.9000 - val_loss: 1.1062 - val_accuracy: 0.7122
#
# Epoch 00059: val_accuracy did not improve from 0.82439
# Epoch 60/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.3909 - accuracy: 0.8937 - val_loss: 0.7150 - val_accuracy: 0.8000
#
# Epoch 00060: val_accuracy did not improve from 0.82439
# Epoch 61/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.3123 - accuracy: 0.9023 - val_loss: 1.0753 - val_accuracy: 0.7439
#
# Epoch 00061: val_accuracy did not improve from 0.82439
# Epoch 62/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.4128 - accuracy: 0.8940 - val_loss: 1.1723 - val_accuracy: 0.7268
#
# Epoch 00062: val_accuracy did not improve from 0.82439
# Epoch 63/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.3310 - accuracy: 0.9081 - val_loss: 0.7484 - val_accuracy: 0.7976
#
# Epoch 00063: val_accuracy did not improve from 0.82439
# Epoch 64/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.3243 - accuracy: 0.9047 - val_loss: 0.7812 - val_accuracy: 0.8098
#
# Epoch 00064: val_accuracy did not improve from 0.82439
# Epoch 65/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.3179 - accuracy: 0.9135 - val_loss: 1.1349 - val_accuracy: 0.7244
#
# Epoch 00065: val_accuracy did not improve from 0.82439
# Epoch 66/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2813 - accuracy: 0.9231 - val_loss: 0.5677 - val_accuracy: 0.8659
#
# Epoch 00066: val_accuracy improved from 0.82439 to 0.86585, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_22.ckpt
# Epoch 67/150
# 409/409 [==============================] - 37s 89ms/step - loss: 0.2822 - accuracy: 0.9195 - val_loss: 0.7724 - val_accuracy: 0.8098
#
# Epoch 00067: val_accuracy did not improve from 0.86585
# Epoch 68/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2883 - accuracy: 0.9185 - val_loss: 1.1671 - val_accuracy: 0.7049
#
# Epoch 00068: val_accuracy did not improve from 0.86585
# Epoch 69/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.3207 - accuracy: 0.9173 - val_loss: 1.0123 - val_accuracy: 0.7195
#
# Epoch 00069: val_accuracy did not improve from 0.86585
# Epoch 70/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2798 - accuracy: 0.9264 - val_loss: 0.6990 - val_accuracy: 0.8317
#
# Epoch 00070: val_accuracy did not improve from 0.86585
# Epoch 71/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2853 - accuracy: 0.9377 - val_loss: 1.1513 - val_accuracy: 0.6927
#
# Epoch 00071: val_accuracy did not improve from 0.86585
# Epoch 72/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2842 - accuracy: 0.9268 - val_loss: 1.1961 - val_accuracy: 0.6756
#
# Epoch 00072: val_accuracy did not improve from 0.86585
# Epoch 73/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2799 - accuracy: 0.9180 - val_loss: 0.7180 - val_accuracy: 0.8122
#
# Epoch 00073: val_accuracy did not improve from 0.86585
# Epoch 74/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.3093 - accuracy: 0.9199 - val_loss: 0.7962 - val_accuracy: 0.8024
#
# Epoch 00074: val_accuracy did not improve from 0.86585
# Epoch 75/150
# 409/409 [==============================] - 36s 89ms/step - loss: 0.2389 - accuracy: 0.9367 - val_loss: 0.9238 - val_accuracy: 0.7585
#
# Epoch 00075: val_accuracy did not improve from 0.86585
# Epoch 76/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.2685 - accuracy: 0.9232 - val_loss: 1.2541 - val_accuracy: 0.6951
#
# Epoch 00076: val_accuracy did not improve from 0.86585
# Epoch 77/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2437 - accuracy: 0.9342 - val_loss: 0.9235 - val_accuracy: 0.7805
#
# Epoch 00077: val_accuracy did not improve from 0.86585
# Epoch 78/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2837 - accuracy: 0.9262 - val_loss: 0.7639 - val_accuracy: 0.7902
#
# Epoch 00078: val_accuracy did not improve from 0.86585
# Epoch 79/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1707 - accuracy: 0.9482 - val_loss: 1.2598 - val_accuracy: 0.6805
#
# Epoch 00079: val_accuracy did not improve from 0.86585
# Epoch 80/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1998 - accuracy: 0.9415 - val_loss: 0.7839 - val_accuracy: 0.7927
#
# Epoch 00080: val_accuracy did not improve from 0.86585
# Epoch 81/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1824 - accuracy: 0.9542 - val_loss: 0.7282 - val_accuracy: 0.8171
#
# Epoch 00081: val_accuracy did not improve from 0.86585
# Epoch 82/150
# 409/409 [==============================] - 36s 89ms/step - loss: 0.1803 - accuracy: 0.9523 - val_loss: 0.8325 - val_accuracy: 0.8024
#
# Epoch 00082: val_accuracy did not improve from 0.86585
# Epoch 83/150
# 409/409 [==============================] - 36s 87ms/step - loss: 0.2378 - accuracy: 0.9466 - val_loss: 0.7673 - val_accuracy: 0.7829
#
# Epoch 00083: val_accuracy did not improve from 0.86585
# Epoch 84/150
# 409/409 [==============================] - 37s 89ms/step - loss: 0.1915 - accuracy: 0.9499 - val_loss: 0.8510 - val_accuracy: 0.8024
#
# Epoch 00084: val_accuracy did not improve from 0.86585
# Epoch 85/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2129 - accuracy: 0.9516 - val_loss: 0.7306 - val_accuracy: 0.8146
#
# Epoch 00085: val_accuracy did not improve from 0.86585
# Epoch 86/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1866 - accuracy: 0.9484 - val_loss: 1.1470 - val_accuracy: 0.7390
#
# Epoch 00086: val_accuracy did not improve from 0.86585
# Epoch 87/150
# 409/409 [==============================] - 36s 89ms/step - loss: 0.2094 - accuracy: 0.9459 - val_loss: 0.8887 - val_accuracy: 0.7829
#
# Epoch 00087: val_accuracy did not improve from 0.86585
# Epoch 88/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1328 - accuracy: 0.9575 - val_loss: 0.9361 - val_accuracy: 0.7585
#
# Epoch 00088: val_accuracy did not improve from 0.86585
# Epoch 89/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2073 - accuracy: 0.9488 - val_loss: 1.3335 - val_accuracy: 0.6415
#
# Epoch 00089: val_accuracy did not improve from 0.86585
# Epoch 90/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1915 - accuracy: 0.9485 - val_loss: 0.8338 - val_accuracy: 0.7854
#
# Epoch 00090: val_accuracy did not improve from 0.86585
# Epoch 91/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2394 - accuracy: 0.9411 - val_loss: 1.0966 - val_accuracy: 0.7610
#
# Epoch 00091: val_accuracy did not improve from 0.86585
# Epoch 92/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1923 - accuracy: 0.9569 - val_loss: 0.9726 - val_accuracy: 0.7610
#
# Epoch 00092: val_accuracy did not improve from 0.86585
# Epoch 93/150
# 409/409 [==============================] - 37s 90ms/step - loss: 0.1807 - accuracy: 0.9457 - val_loss: 1.2063 - val_accuracy: 0.7341
#
# Epoch 00093: val_accuracy did not improve from 0.86585
# Epoch 94/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1362 - accuracy: 0.9607 - val_loss: 1.2542 - val_accuracy: 0.7512
#
# Epoch 00094: val_accuracy did not improve from 0.86585
# Epoch 95/150
# 409/409 [==============================] - 37s 91ms/step - loss: 0.1649 - accuracy: 0.9561 - val_loss: 1.0758 - val_accuracy: 0.7585
#
# Epoch 00095: val_accuracy did not improve from 0.86585
# Epoch 96/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1849 - accuracy: 0.9603 - val_loss: 1.0309 - val_accuracy: 0.7927
#
# Epoch 00096: val_accuracy did not improve from 0.86585
# Epoch 97/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1885 - accuracy: 0.9526 - val_loss: 0.8947 - val_accuracy: 0.7878
#
# Epoch 00097: val_accuracy did not improve from 0.86585
# Epoch 98/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1743 - accuracy: 0.9597 - val_loss: 0.9622 - val_accuracy: 0.7756
#
# Epoch 00098: val_accuracy did not improve from 0.86585
# Epoch 99/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1896 - accuracy: 0.9575 - val_loss: 1.2348 - val_accuracy: 0.6805
#
# Epoch 00099: val_accuracy did not improve from 0.86585
# Epoch 100/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1828 - accuracy: 0.9603 - val_loss: 0.8543 - val_accuracy: 0.8024
#
# Epoch 00100: val_accuracy did not improve from 0.86585
# Epoch 101/150
# 409/409 [==============================] - 37s 89ms/step - loss: 0.1871 - accuracy: 0.9494 - val_loss: 0.9612 - val_accuracy: 0.7854
#
# Epoch 00101: val_accuracy did not improve from 0.86585
# Epoch 102/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1169 - accuracy: 0.9721 - val_loss: 1.0411 - val_accuracy: 0.7707
#
# Epoch 00102: val_accuracy did not improve from 0.86585
# Epoch 103/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1930 - accuracy: 0.9650 - val_loss: 0.9388 - val_accuracy: 0.7829
#
# Epoch 00103: val_accuracy did not improve from 0.86585
# Epoch 104/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1200 - accuracy: 0.9748 - val_loss: 1.0500 - val_accuracy: 0.7732
#
# Epoch 00104: val_accuracy did not improve from 0.86585
# Epoch 105/150
# 409/409 [==============================] - 36s 89ms/step - loss: 0.1726 - accuracy: 0.9595 - val_loss: 0.9078 - val_accuracy: 0.7951
#
# Epoch 00105: val_accuracy did not improve from 0.86585
# Epoch 106/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1465 - accuracy: 0.9692 - val_loss: 0.9408 - val_accuracy: 0.7976
#
# Epoch 00106: val_accuracy did not improve from 0.86585
# Epoch 107/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.2128 - accuracy: 0.9482 - val_loss: 1.0314 - val_accuracy: 0.7878
#
# Epoch 00107: val_accuracy did not improve from 0.86585
# Epoch 108/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1982 - accuracy: 0.9572 - val_loss: 0.8103 - val_accuracy: 0.8293
#
# Epoch 00108: val_accuracy did not improve from 0.86585
# Epoch 109/150
# 409/409 [==============================] - 37s 90ms/step - loss: 0.1621 - accuracy: 0.9614 - val_loss: 0.7082 - val_accuracy: 0.8415
#
# Epoch 00109: val_accuracy did not improve from 0.86585
# Epoch 110/150
# 409/409 [==============================] - 37s 89ms/step - loss: 0.1102 - accuracy: 0.9792 - val_loss: 1.0949 - val_accuracy: 0.7488
#
# Epoch 00110: val_accuracy did not improve from 0.86585
# Epoch 111/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1067 - accuracy: 0.9716 - val_loss: 0.8094 - val_accuracy: 0.8220
#
# Epoch 00111: val_accuracy did not improve from 0.86585
# Epoch 112/150
# 409/409 [==============================] - 36s 89ms/step - loss: 0.1478 - accuracy: 0.9626 - val_loss: 1.0062 - val_accuracy: 0.8000
#
# Epoch 00112: val_accuracy did not improve from 0.86585
# Epoch 113/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1286 - accuracy: 0.9682 - val_loss: 0.9133 - val_accuracy: 0.8098
#
# Epoch 00113: val_accuracy did not improve from 0.86585
# Epoch 114/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1381 - accuracy: 0.9559 - val_loss: 0.9427 - val_accuracy: 0.8146
#
# Epoch 00114: val_accuracy did not improve from 0.86585
# Epoch 115/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1161 - accuracy: 0.9710 - val_loss: 1.0007 - val_accuracy: 0.8098
#
# Epoch 00115: val_accuracy did not improve from 0.86585
# Epoch 116/150
# 409/409 [==============================] - 36s 88ms/step - loss: 0.1123 - accuracy: 0.9745 - val_loss: 0.8818 - val_accuracy: 0.8049
#
# Epoch 00116: val_accuracy did not improve from 0.86585
# Epoch 00116: early stopping
# Fold:  3
# Epoch 1/150
# 409/409 [==============================] - 64s 96ms/step - loss: 6.4797 - accuracy: 0.0988 - val_loss: 2.4831 - val_accuracy: 0.1073
#
# Epoch 00001: val_accuracy improved from -inf to 0.10732, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_23.ckpt
# Epoch 2/150
# 409/409 [==============================] - 37s 90ms/step - loss: 3.0283 - accuracy: 0.1046 - val_loss: 2.8153 - val_accuracy: 0.1122
#
# Epoch 00002: val_accuracy improved from 0.10732 to 0.11220, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_23.ckpt
# Epoch 3/150
# 409/409 [==============================] - 37s 90ms/step - loss: 2.8717 - accuracy: 0.0882 - val_loss: 2.7310 - val_accuracy: 0.0902
#
# Epoch 00003: val_accuracy did not improve from 0.11220
# Epoch 4/150
# 409/409 [==============================] - 36s 89ms/step - loss: 2.7569 - accuracy: 0.0987 - val_loss: 2.4710 - val_accuracy: 0.0854
#
# Epoch 00004: val_accuracy did not improve from 0.11220
# Epoch 5/150
# 409/409 [==============================] - 36s 89ms/step - loss: 2.6740 - accuracy: 0.1091 - val_loss: 2.6334 - val_accuracy: 0.0902
#
# ...
# Epoch 106/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.3457 - accuracy: 0.9152 - val_loss: 1.0038 - val_accuracy: 0.7707
#
# Epoch 00106: val_accuracy did not improve from 0.83902
# Epoch 107/150
# 409/409 [==============================] - 37s 91ms/step - loss: 0.2759 - accuracy: 0.9311 - val_loss: 0.8094 - val_accuracy: 0.7927
#
# Epoch 00107: val_accuracy did not improve from 0.83902
# Epoch 108/150
# 409/409 [==============================] - 37s 92ms/step - loss: 0.2293 - accuracy: 0.9319 - val_loss: 0.8604 - val_accuracy: 0.8195
#
# Epoch 00108: val_accuracy did not improve from 0.83902
# Epoch 109/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.2846 - accuracy: 0.9298 - val_loss: 1.1556 - val_accuracy: 0.7512
#
# Epoch 00109: val_accuracy did not improve from 0.83902
# Epoch 110/150
# 409/409 [==============================] - 37s 91ms/step - loss: 0.2849 - accuracy: 0.9251 - val_loss: 0.9235 - val_accuracy: 0.7902
#
# Epoch 00110: val_accuracy did not improve from 0.83902
# Epoch 111/150
# 409/409 [==============================] - 37s 92ms/step - loss: 0.3057 - accuracy: 0.9278 - val_loss: 0.8312 - val_accuracy: 0.8122
#
# Epoch 00111: val_accuracy did not improve from 0.83902
# Epoch 112/150
# 409/409 [==============================] - 39s 96ms/step - loss: 0.2026 - accuracy: 0.9472 - val_loss: 0.8646 - val_accuracy: 0.8024
#
# Epoch 00112: val_accuracy did not improve from 0.83902
# Epoch 113/150
# 409/409 [==============================] - 38s 93ms/step - loss: 0.2995 - accuracy: 0.9142 - val_loss: 0.9104 - val_accuracy: 0.8073
#
# Epoch 00113: val_accuracy did not improve from 0.83902
# Epoch 114/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.2245 - accuracy: 0.9458 - val_loss: 1.1461 - val_accuracy: 0.7488
#
# Epoch 00114: val_accuracy did not improve from 0.83902
# Epoch 115/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.1693 - accuracy: 0.9507 - val_loss: 0.7991 - val_accuracy: 0.8195
#
# Epoch 00115: val_accuracy did not improve from 0.83902
# Epoch 116/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.2416 - accuracy: 0.9306 - val_loss: 1.5631 - val_accuracy: 0.6756
#
# Epoch 00116: val_accuracy did not improve from 0.83902
# Epoch 117/150
# 409/409 [==============================] - 38s 93ms/step - loss: 0.2233 - accuracy: 0.9444 - val_loss: 1.0643 - val_accuracy: 0.7683
#
# Epoch 00117: val_accuracy did not improve from 0.83902
# Epoch 118/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.1774 - accuracy: 0.9487 - val_loss: 0.8991 - val_accuracy: 0.8000
#
# Epoch 00118: val_accuracy did not improve from 0.83902
# Epoch 119/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.2323 - accuracy: 0.9351 - val_loss: 0.8220 - val_accuracy: 0.8195
#
# Epoch 00119: val_accuracy did not improve from 0.83902
# Epoch 120/150
# 409/409 [==============================] - 38s 93ms/step - loss: 0.2046 - accuracy: 0.9476 - val_loss: 1.0177 - val_accuracy: 0.7878
#
# Epoch 00120: val_accuracy did not improve from 0.83902
# Epoch 121/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.2345 - accuracy: 0.9406 - val_loss: 0.8329 - val_accuracy: 0.8049
#
# Epoch 00121: val_accuracy did not improve from 0.83902
# Epoch 122/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.2745 - accuracy: 0.9374 - val_loss: 0.8783 - val_accuracy: 0.8098
#
# Epoch 00122: val_accuracy did not improve from 0.83902
# Epoch 123/150
# 409/409 [==============================] - 39s 96ms/step - loss: 0.1996 - accuracy: 0.9487 - val_loss: 0.9280 - val_accuracy: 0.7805
#
# Epoch 00123: val_accuracy did not improve from 0.83902
# Epoch 124/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.2492 - accuracy: 0.9352 - val_loss: 0.8935 - val_accuracy: 0.8073
#
# Epoch 00124: val_accuracy did not improve from 0.83902
# Epoch 125/150
# 409/409 [==============================] - 38s 93ms/step - loss: 0.1788 - accuracy: 0.9584 - val_loss: 1.0912 - val_accuracy: 0.7732
#
# Epoch 00125: val_accuracy did not improve from 0.83902
# Epoch 126/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.2133 - accuracy: 0.9390 - val_loss: 0.9916 - val_accuracy: 0.8024
#
# Epoch 00126: val_accuracy did not improve from 0.83902
# Epoch 127/150
# 409/409 [==============================] - 38s 92ms/step - loss: 0.2160 - accuracy: 0.9381 - val_loss: 1.1010 - val_accuracy: 0.7805
#
# Epoch 00127: val_accuracy did not improve from 0.83902
# Epoch 128/150
# 409/409 [==============================] - 38s 93ms/step - loss: 0.1620 - accuracy: 0.9528 - val_loss: 0.9682 - val_accuracy: 0.8024
#
# Epoch 00128: val_accuracy did not improve from 0.83902
# Epoch 129/150
# 409/409 [==============================] - 38s 93ms/step - loss: 0.2064 - accuracy: 0.9471 - val_loss: 0.8381 - val_accuracy: 0.8317
#
# Epoch 00129: val_accuracy did not improve from 0.83902
# Epoch 130/150
# 409/409 [==============================] - 38s 93ms/step - loss: 0.2298 - accuracy: 0.9454 - val_loss: 0.8416 - val_accuracy: 0.8122
#
# Epoch 00130: val_accuracy did not improve from 0.83902
# Epoch 131/150
# 409/409 [==============================] - 38s 93ms/step - loss: 0.1605 - accuracy: 0.9557 - val_loss: 0.8784 - val_accuracy: 0.8146
#
# Epoch 00131: val_accuracy did not improve from 0.83902
# Epoch 132/150
# 409/409 [==============================] - 38s 93ms/step - loss: 0.2326 - accuracy: 0.9480 - val_loss: 0.8924 - val_accuracy: 0.8000
#
# Epoch 00132: val_accuracy did not improve from 0.83902
# Epoch 133/150
# 409/409 [==============================] - 38s 94ms/step - loss: 0.1533 - accuracy: 0.9596 - val_loss: 0.9084 - val_accuracy: 0.8098
#
# Epoch 00133: val_accuracy did not improve from 0.83902
# Epoch 134/150
# 409/409 [==============================] - 38s 93ms/step - loss: 0.1912 - accuracy: 0.9527 - val_loss: 0.9787 - val_accuracy: 0.8195
#
# Epoch 00134: val_accuracy did not improve from 0.83902
# Epoch 135/150
# 409/409 [==============================] - 38s 93ms/step - loss: 0.2119 - accuracy: 0.9505 - val_loss: 1.0539 - val_accuracy: 0.7878
#
# Epoch 00135: val_accuracy did not improve from 0.83902
# Epoch 136/150
# 409/409 [==============================] - 38s 93ms/step - loss: 0.1288 - accuracy: 0.9685 - val_loss: 1.0130 - val_accuracy: 0.8098
#
# Epoch 00136: val_accuracy did not improve from 0.83902
# Epoch 00136: early stopping
# Fold:  12
# Epoch 1/150
# 409/409 [==============================] - 65s 101ms/step - loss: 6.6036 - accuracy: 0.1074 - val_loss: 2.6086 - val_accuracy: 0.1293
#
# Epoch 00001: val_accuracy improved from -inf to 0.12927, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_212.ckpt
# Epoch 2/150
# 409/409 [==============================] - 38s 94ms/step - loss: 2.9171 - accuracy: 0.1033 - val_loss: 3.6976 - val_accuracy: 0.1244
#
# Epoch 00002: val_accuracy did not improve from 0.12927
# Epoch 3/150
# 409/409 [==============================] - 38s 93ms/step - loss: 2.8288 - accuracy: 0.1064 - val_loss: 2.5407 - val_accuracy: 0.1293
#
# Epoch 00003: val_accuracy did not improve from 0.12927
# Epoch 4/150
# 409/409 [==============================] - 39s 95ms/step - loss: 2.7713 - accuracy: 0.1023 - val_loss: 2.9241 - val_accuracy: 0.1537
#
# Epoch 00004: val_accuracy improved from 0.12927 to 0.15366, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_212.ckpt
# Epoch 5/150
# 409/409 [==============================] - 39s 95ms/step - loss: 2.6336 - accuracy: 0.1086 - val_loss: 2.3364 - val_accuracy: 0.1049
#
# Epoch 00005: val_accuracy did not improve from 0.15366
# Epoch 6/150
# 409/409 [==============================] - 40s 97ms/step - loss: 2.5909 - accuracy: 0.1058 - val_loss: 2.4944 - val_accuracy: 0.1098
#
# Epoch 00006: val_accuracy did not improve from 0.15366
# Epoch 7/150
# 409/409 [==============================] - 38s 93ms/step - loss: 2.5613 - accuracy: 0.0912 - val_loss: 2.5146 - val_accuracy: 0.0951
#
# Epoch 00007: val_accuracy did not improve from 0.15366
# Epoch 8/150
# 409/409 [==============================] - 38s 93ms/step - loss: 2.5348 - accuracy: 0.1168 - val_loss: 2.3465 - val_accuracy: 0.0854
#
# Epoch 00008: val_accuracy did not improve from 0.15366
# Epoch 9/150
# 409/409 [==============================] - 38s 93ms/step - loss: 2.4654 - accuracy: 0.0905 - val_loss: 2.3392 - val_accuracy: 0.0927
#
# Epoch 00009: val_accuracy did not improve from 0.15366
# Epoch 10/150
# 409/409 [==============================] - 39s 94ms/step - loss: 2.4484 - accuracy: 0.0909 - val_loss: 2.3526 - val_accuracy: 0.1268
#
# Epoch 00010: val_accuracy did not improve from 0.15366
# Epoch 11/150
# 409/409 [==============================] - 38s 94ms/step - loss: 2.4468 - accuracy: 0.1084 - val_loss: 2.3942 - val_accuracy: 0.0780
#
# Epoch 00011: val_accuracy did not improve from 0.15366
# Epoch 12/150
# 409/409 [==============================] - 39s 94ms/step - loss: 2.4249 - accuracy: 0.1067 - val_loss: 2.3038 - val_accuracy: 0.0902
#
# Epoch 00012: val_accuracy did not improve from 0.15366
# Epoch 13/150
# 409/409 [==============================] - 38s 94ms/step - loss: 2.3930 - accuracy: 0.0981 - val_loss: 2.3174 - val_accuracy: 0.1146
#
# Epoch 00013: val_accuracy did not improve from 0.15366
# Epoch 14/150
# 409/409 [==============================] - 38s 94ms/step - loss: 2.3738 - accuracy: 0.1190 - val_loss: 2.2983 - val_accuracy: 0.0854
#
# Epoch 00014: val_accuracy did not improve from 0.15366
# Epoch 15/150
# 409/409 [==============================] - 38s 93ms/step - loss: 2.3127 - accuracy: 0.1379 - val_loss: 2.1593 - val_accuracy: 0.1805
#
# Epoch 00015: val_accuracy improved from 0.15366 to 0.18049, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_212.ckpt
# Epoch 16/150
# 409/409 [==============================] - 39s 96ms/step - loss: 2.2267 - accuracy: 0.1824 - val_loss: 2.0838 - val_accuracy: 0.1854
#
# Epoch 00016: val_accuracy improved from 0.18049 to 0.18537, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_212.ckpt
# Epoch 17/150
# 409/409 [==============================] - 40s 97ms/step - loss: 2.0763 - accuracy: 0.2103 - val_loss: 1.9648 - val_accuracy: 0.2073
#
# Epoch 00017: val_accuracy improved from 0.18537 to 0.20732, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_212.ckpt
# Epoch 18/150
# 409/409 [==============================] - 38s 94ms/step - loss: 2.0129 - accuracy: 0.2573 - val_loss: 1.6532 - val_accuracy: 0.3854
#
# Epoch 00018: val_accuracy improved from 0.20732 to 0.38537, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_212.ckpt
# Epoch 19/150
# 409/409 [==============================] - 38s 94ms/step - loss: 1.8817 - accuracy: 0.3361 - val_loss: 1.6749 - val_accuracy: 0.4122
#
# Epoch 00019: val_accuracy improved from 0.38537 to 0.41220, saving model to /content/drive/MyDrive/colab_data/modelcheckpoint/dacon3/effi_model_aug_212.ckpt
# Epoch 20/150
# 409/409 [==============================] - 39s 96ms/step - loss: 1.7190 - accuracy: 0.3741 - val_loss: 1.6737 - val_accuracy: 0.3829
#
# Epoch 00020: val_accuracy did not improve from 0.41220
# Epoch 21/150
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b2a49324aebc> in <module>()
#     161                shuffle=True,
#     162                validation_data=validation_generator,
# --> 163                steps_per_epoch =len(X_train)//4
#     164                )
#     165     del X_train
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1103               logs = tmp_logs  # No error, now safe to assign to logs.
#    1104               end_step = step + data_handler.step_increment
# -> 1105               callbacks.on_train_batch_end(end_step, logs)
#    1106               if self.stop_training:
#    1107                 break
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     452     """
#     453     if self._should_call_train_batch_hooks:
# --> 454       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     455
#     456   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     294       self._call_batch_begin_hook(mode, batch, logs)
#     295     elif hook == 'end':
# --> 296       self._call_batch_end_hook(mode, batch, logs)
#     297     else:
#     298       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354       hook = getattr(callback, hook_name)
#     355       if getattr(callback, '_supports_tf_logs', False):
# --> 356         hook(batch, logs)
#     357       else:
#     358         if numpy_logs is None:  # Only convert once.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1018
#    1019   def on_train_batch_end(self, batch, logs=None):
# -> 1020     self._batch_update_progbar(batch, logs)
#    1021
#    1022   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1083       # Only block async when verbose = 1.
#    1084       logs = tf_utils.to_numpy_or_python_type(logs)
# -> 1085       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1086
#    1087   def _finalize_progbar(self, logs, counter):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/generic_utils.py in update(self, current, values, finalize)
#     576       if self._dynamic_display:
#     577         sys.stdout.write('\b' * prev_total_width)
# --> 578         sys.stdout.write('\r')
#     579       else:
#     580         sys.stdout.write('\n')
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
